# %%
import numpy as np, pandas as pd
X = np.load("/home/yesong/CausalPFN-DML/external/openml/credit_X.npy")
print(X.shape)  # (49842, 15) 기대
print(pd.read_csv("/home/yesong/CausalPFN-DML/external/uci/census_X.csv").shape[1])  # 15 기대
# Out:
# (49842, 15)
# 15
